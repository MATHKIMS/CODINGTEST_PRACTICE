# %% [markdown]
# <a href="https://colab.research.google.com/github/MATHKIMS/CODINGTEST_PRACTICE/blob/main/230414%5B%EB%B0%B1%EC%A4%8010172%5D_%EA%B0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 문제: 아래와 같이 개를 출력하여라

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("|\_/|")
print("|q p|   /}")
print('( 0 )"""\\')  
print('|"^"`    |')
print("||_/=\\\__|")
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|
